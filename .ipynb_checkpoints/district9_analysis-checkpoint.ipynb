# %%
# load libraries
import pandas as pd
import openpyxl
import geopandas as gpd

# %% [markdown]
# ## Clean up data and merge dfs

# %%
# import election results for state senate district 9
district9_results = pd.read_excel('data/detail.xlsx', sheet_name='2', skiprows=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# this spreadsheet has multi-level headers, so we'll need to address that
district9_results.head()
# Out:
#   Unnamed: 0         Unnamed: 1 Taylor Rehmet Unnamed: 3 Unnamed: 4  \
# 0   Precinct  Registered Voters      Absentee      Early   Election
# 1       1001               1940             3         99         98
# 2       1005                942             3         21         51
# 3       1008                314             1         12         24
# 4       1010                698             1          0         20
#
#     Unnamed: 5 Leigh Wambsganss Unnamed: 7 Unnamed: 8   Unnamed: 9 Unnamed: 10
# 0  Total Votes         Absentee      Early   Election  Total Votes       Total
# 1          200                1         43         45           89         289
# 2           75                0          1          2            3          78
# 3           37                0          0          6            6          43
# 4           21                0          2          0            2          23

# %%
# rename columns to combine candidate names with vote types -- essentially flatten since there are multiple levels of headers
district9_results.columns = [
    'Precinct',
    'Registered_Voters',
    'Absentee_TaylorRehmet',
    'Early_TaylorRehmet',
    'Election_TaylorRehmet',
    'TotalVotes_TaylorRehmet',
    'Absentee_LeighWambsganss',
    'Early_LeighWambsganss',
    'Election_LeighWambsganss',
    'TotalVotes_LeighWambsganss',
    'TotalVotesAll'
]

# drop first row so we only have one row of headers
district9_results = district9_results.drop(0).reset_index(drop=True)

# make sure everything looks right
district9_results.head()
# Out:
#   Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 0     1001              1940                     3                 99
# 1     1005               942                     3                 21
# 2     1008               314                     1                 12
# 3     1010               698                     1                  0
# 4     1011              1134                     3                 19
#
#   Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 0                    98                     200                        1
# 1                    51                      75                        0
# 2                    24                      37                        0
# 3                    20                      21                        0
# 4                    45                      67                        0
#
#   Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 0                    43                       45                         89
# 1                     1                        2                          3
# 2                     0                        6                          6
# 3                     2                        0                          2
# 4                     2                        3                          5
#
#   TotalVotesAll
# 0           289
# 1            78
# 2            43
# 3            23
# 4            72

# %%
# there's a total row we don't want at the end, so let's drop that
district9_results.tail()
# Out:
#     Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 376     4836              3126                    10                 76
# 377     4844              1820                     2                 40
# 378     4846              1720                     3                 49
# 379     4849              3336                     1                 83
# 380   Total:            617753                  1115              24571
#
#     Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 376                   123                     209                        4
# 377                    73                     115                        0
# 378                    39                      91                        2
# 379                   137                     221                        0
# 380                 28594                   54280                      608
#
#     Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 376                    67                       56                        127
# 377                    29                       44                         73
# 378                    16                       33                         51
# 379                    39                       81                        120
# 380                 19375                    20617                      40600
#
#     TotalVotesAll
# 376           336
# 377           188
# 378           142
# 379           341
# 380         94880

# %%
# drop last row
district9_results = district9_results.iloc[:-1].reset_index(drop=True)

# %%
# double check the bottom of the df looks good
district9_results.tail()
# Out:
#     Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 375     4833              2116                     2                 78
# 376     4836              3126                    10                 76
# 377     4844              1820                     2                 40
# 378     4846              1720                     3                 49
# 379     4849              3336                     1                 83
#
#     Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 375                   114                     194                        1
# 376                   123                     209                        4
# 377                    73                     115                        0
# 378                    39                      91                        2
# 379                   137                     221                        0
#
#     Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 375                   100                      108                        209
# 376                    67                       56                        127
# 377                    29                       44                         73
# 378                    16                       33                         51
# 379                    39                       81                        120
#
#     TotalVotesAll
# 375           403
# 376           336
# 377           188
# 378           142
# 379           341

# %%
# how many rows in the dataframe?
len(district9_results)
# Out:
# 380

# %%
# verify types
district9_results.dtypes
# Out:
# Precinct                      object
# Registered_Voters             object
# Absentee_TaylorRehmet         object
# Early_TaylorRehmet            object
# Election_TaylorRehmet         object
# TotalVotes_TaylorRehmet       object
# Absentee_LeighWambsganss      object
# Early_LeighWambsganss         object
# Election_LeighWambsganss      object
# TotalVotes_LeighWambsganss    object
# TotalVotesAll                 object
# dtype: object

# %%
# read in vtd census demographics data
vtd_census_2020 = pd.read_csv('data/vtd_census - VTDs_24PG_Pop.csv')

# %%
# this has demographics for all of the precincts in texas
len(vtd_census_2020)
# Out:
# 9712

# %%
vtd_census_2020.dtypes
# Out:
# CountyFIPS     int64
# County        object
# CNTY           int64
# VTD           object
# CNTYVTD       object
# VTDKEY         int64
# total          int64
# anglo          int64
# nanglo         int64
# asian          int64
# black          int64
# hisp           int64
# bh             int64
# vap            int64
# anglovap       int64
# nanglovap      int64
# asianvap       int64
# blackvap       int64
# hispvap        int64
# bhvap          int64
# dtype: object

# %%
# ensure type is string so join works properly
vtd_census_2020['VTD'] = vtd_census_2020['VTD'].astype(str)

# %%
# we're lucky that all of district 9 is in tarrant county, so can filter to just that
vtd_census_tarrant = vtd_census_2020[vtd_census_2020['County'] == 'TARRANT']

# %%
vtd_census_tarrant.duplicated(subset=['VTD']).sum()
# Out:
# 0

# %% [markdown]
# I looked at this data in QGIS as well, and saw that six precincts were missing from the VTD data.
#
# Four were missing because in the VTD data, they had suffixes like A or B. These were missing initially:
# - 4737 is split into 4737A and 4737B
# - 4846 is split into 4846A and 4846B
# - 4245 is split into 4245A and 4245B
# - 3325 is split into 3325A and 3325B
#
# The following were also missing from the VTD data, but these were gone entirely:
# - Precinct 1823 NOT found in vtd_census_2020
# - Precinct 4598 NOT found in vtd_census_2020
#
# Looking back at the election results data, each of these precincts had zero votes.

# %%
# let's aggregate the demographics across precincts with A and B suffixes

# create base column that strips the A/B suffix
vtd_census_tarrant['VTD_base'] = vtd_census_tarrant['VTD'].str.rstrip('AB')

# identify which VTDs we are adding combined
combined_vtds = vtd_census_tarrant.groupby('VTD_base').filter(lambda x: len(x) > 1)
if len(combined_vtds) > 0:
    print("VTDs that will be combined:")
    for base_vtd in combined_vtds['VTD_base'].unique():
        variants = vtd_census_tarrant[vtd_census_tarrant['VTD_base'] == base_vtd]['VTD'].tolist()
        print(f"  {base_vtd}: {', '.join(variants)}")
    print()

# specify which columns to sum when combining A and B precincts
cols_to_add = ['total',
               'anglo',
               'nanglo',
               'asian',
               'black',
               'hisp',
               'bh',
               'vap',
               'anglovap',
               'nanglovap',
               'asianvap',
               'blackvap',
               'hispvap',
               'bhvap']

# we want to group by the stripped VTD name and sum specified columns, keep first value for others
agg_dict = {col: 'sum' if col in cols_to_add else 'first' 
            for col in vtd_census_tarrant.columns if col not in ['VTD', 'VTD_base']}

vtd_census_combined = vtd_census_tarrant.groupby('VTD_base', as_index=False).agg(agg_dict)

# rename VTD_base back to VTD
vtd_census_combined.rename(columns={'VTD_base': 'VTD'}, inplace=True)

print(f"Original Tarrant VTDs: {len(vtd_census_tarrant)}")
print(f"Combined VTDs: {len(vtd_census_combined)}")
# Out:
# VTDs that will be combined:
#   2827: 2827A, 2827B
#   3325: 3325A, 3325B
#   4245: 4245A, 4245B
#   4737: 4737A, 4737B
#   4846: 4846A, 4846B
#
# Original Tarrant VTDs: 782
# Combined VTDs: 777
# /var/folders/sv/fm7yfyrs7317lzyxf_8p39800000gn/T/ipykernel_27757/2427489598.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vtd_census_tarrant['VTD_base'] = vtd_census_tarrant['VTD'].str.rstrip('AB')

# %%
# join both data frames on Precinct and VTD
# the key to join is NOT vtdkey -- values for that are as low as 1. there's no precinct 1 in district 9

merged_df = pd.merge(district9_results, vtd_census_combined, left_on='Precinct', right_on='VTD', how='inner')

# %%
# are there any duplicate precincts now?
merged_df.duplicated(subset=['Precinct']).sum()
# Out:
# 0

# %%
# how many precincts are missing?
len(merged_df)
# Out:
# 378

# %%
# show precincts that are in in district9_results but not in merged_df
precincts_in_original = set(district9_results['Precinct'])
precincts_in_merged = set(merged_df['Precinct'])
missing_precincts = precincts_in_original - precincts_in_merged

print(f"Precincts not in merged: {len(missing_precincts)}")
if missing_precincts:
    print("Missing precincts:")
    for p in missing_precincts:
        print(f"{p}")
# Out:
# Precincts not in merged: 2
# Missing precincts:
# 4598
# 1823

# %%
# check if these missing precincts are in original vtd_census_2020 data
for precinct in missing_precincts:
    match = vtd_census_2020[vtd_census_2020['VTD'] == precinct]
    if len(match) > 0:
        print(f"Precinct {precinct} found in vtd_census_2020:")
        print(f"  Counties: {match['County'].unique().tolist()}")
    else:
        print(f"Precinct {precinct} not in vtd_census_2020")
# Out:
# Precinct 4598 not in vtd_census_2020
# Precinct 1823 not in vtd_census_2020

# %%
# see these rows in the election results data 
# each of them have zero total votes
district9_results[district9_results['Precinct'].isin(['1823', '4598'])]
# Out:
#     Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 75      1823                 0                     0                  0
# 339     4598                 0                     0                  0
#
#     Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 75                      0                       0                        0
# 339                     0                       0                        0
#
#     Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 75                      0                        0                          0
# 339                     0                        0                          0
#
#     TotalVotesAll
# 75              0
# 339             0

# %%
# were there other precincts with zero total votes?
# this is weird because there are others with no votes but they still show up
district9_results[district9_results['TotalVotesAll'] == 0]
# Out:
#     Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 11      1064                 0                     0                  0
# 38      1420                 0                     0                  0
# 40      1434                 0                     0                  0
# 42      1455                 0                     0                  0
# 43      1457                 2                     0                  0
# 49      1491                 5                     0                  0
# 50      1544                11                     0                  0
# 51      1547                 0                     0                  0
# 52      1549                 0                     0                  0
# 54      1586                11                     0                  0
# 56      1607                 0                     0                  0
# 62      1623                 1                     0                  0
# 63      1625                 0                     0                  0
# 65      1672                 0                     0                  0
# 66      1674                 0                     0                  0
# 69      1679                 0                     0                  0
# 75      1823                 0                     0                  0
# 113     3185                 2                     0                  0
# 149     3406                 0                     0                  0
# 150     3409                53                     0                  0
# 154     3447                 0                     0                  0
# 172     3560                 0                     0                  0
# 175     3575                 0                     0                  0
# 177     3580                 0                     0                  0
# 179     3583                 0                     0                  0
# 180     3584                 0                     0                  0
# 181     3585                 0                     0                  0
# 182     3590                 0                     0                  0
# 189     3653                 0                     0                  0
# 190     3654                 0                     0                  0
# 191     3661                 0                     0                  0
# 192     3664                 0                     0                  0
# 209     3750                 0                     0                  0
# 210     3822                 0                     0                  0
# 227     4051                14                     0                  0
# 290     4362                 9                     0                  0
# 292     4370                 0                     0                  0
# 308     4478                 0                     0                  0
# 312     4487                 0                     0                  0
# 320     4512                 0                     0                  0
# 328     4563                 0                     0                  0
# 332     4573                 0                     0                  0
# 335     4592                 0                     0                  0
# 339     4598                 0                     0                  0
# 341     4602                 0                     0                  0
# 342     4604                 1                     0                  0
# 343     4615                 0                     0                  0
# 345     4629                 0                     0                  0
# 346     4632                 0                     0                  0
# 352     4666                 0                     0                  0
# 354     4683                 0                     0                  0
# 356     4686                 0                     0                  0
# 371     4820                 0                     0                  0
#
#     Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 11                      0                       0                        0
# 38                      0                       0                        0
# 40                      0                       0                        0
# 42                      0                       0                        0
# 43                      0                       0                        0
# 49                      0                       0                        0
# 50                      0                       0                        0
# 51                      0                       0                        0
# 52                      0                       0                        0
# 54                      0                       0                        0
# 56                      0                       0                        0
# 62                      0                       0                        0
# 63                      0                       0                        0
# 65                      0                       0                        0
# 66                      0                       0                        0
# 69                      0                       0                        0
# 75                      0                       0                        0
# 113                     0                       0                        0
# 149                     0                       0                        0
# 150                     0                       0                        0
# 154                     0                       0                        0
# 172                     0                       0                        0
# 175                     0                       0                        0
# 177                     0                       0                        0
# 179                     0                       0                        0
# 180                     0                       0                        0
# 181                     0                       0                        0
# 182                     0                       0                        0
# 189                     0                       0                        0
# 190                     0                       0                        0
# 191                     0                       0                        0
# 192                     0                       0                        0
# 209                     0                       0                        0
# 210                     0                       0                        0
# 227                     0                       0                        0
# 290                     0                       0                        0
# 292                     0                       0                        0
# 308                     0                       0                        0
# 312                     0                       0                        0
# 320                     0                       0                        0
# 328                     0                       0                        0
# 332                     0                       0                        0
# 335                     0                       0                        0
# 339                     0                       0                        0
# 341                     0                       0                        0
# 342                     0                       0                        0
# 343                     0                       0                        0
# 345                     0                       0                        0
# 346                     0                       0                        0
# 352                     0                       0                        0
# 354                     0                       0                        0
# 356                     0                       0                        0
# 371                     0                       0                        0
#
#     Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 11                      0                        0                          0
# 38                      0                        0                          0
# 40                      0                        0                          0
# 42                      0                        0                          0
# 43                      0                        0                          0
# 49                      0                        0                          0
# 50                      0                        0                          0
# 51                      0                        0                          0
# 52                      0                        0                          0
# 54                      0                        0                          0
# 56                      0                        0                          0
# 62                      0                        0                          0
# 63                      0                        0                          0
# 65                      0                        0                          0
# 66                      0                        0                          0
# 69                      0                        0                          0
# 75                      0                        0                          0
# 113                     0                        0                          0
# 149                     0                        0                          0
# 150                     0                        0                          0
# 154                     0                        0                          0
# 172                     0                        0                          0
# 175                     0                        0                          0
# 177                     0                        0                          0
# 179                     0                        0                          0
# 180                     0                        0                          0
# 181                     0                        0                          0
# 182                     0                        0                          0
# 189                     0                        0                          0
# 190                     0                        0                          0
# 191                     0                        0                          0
# 192                     0                        0                          0
# 209                     0                        0                          0
# 210                     0                        0                          0
# 227                     0                        0                          0
# 290                     0                        0                          0
# 292                     0                        0                          0
# 308                     0                        0                          0
# 312                     0                        0                          0
# 320                     0                        0                          0
# 328                     0                        0                          0
# 332                     0                        0                          0
# 335                     0                        0                          0
# 339                     0                        0                          0
# 341                     0                        0                          0
# 342                     0                        0                          0
# 343                     0                        0                          0
# 345                     0                        0                          0
# 346                     0                        0                          0
# 352                     0                        0                          0
# 354                     0                        0                          0
# 356                     0                        0                          0
# 371                     0                        0                          0
#
#     TotalVotesAll
# 11              0
# 38              0
# 40              0
# 42              0
# 43              0
# 49              0
# 50              0
# 51              0
# 52              0
# 54              0
# 56              0
# 62              0
# 63              0
# 65              0
# 66              0
# 69              0
# 75              0
# 113             0
# 149             0
# 150             0
# 154             0
# 172             0
# 175             0
# 177             0
# 179             0
# 180             0
# 181             0
# 182             0
# 189             0
# 190             0
# 191             0
# 192             0
# 209             0
# 210             0
# 227             0
# 290             0
# 292             0
# 308             0
# 312             0
# 320             0
# 328             0
# 332             0
# 335             0
# 339             0
# 341             0
# 342             0
# 343             0
# 345             0
# 346             0
# 352             0
# 354             0
# 356             0
# 371             0

# %%
# check for nas
merged_df.isna().sum()
# Out:
# Precinct                      0
# Registered_Voters             0
# Absentee_TaylorRehmet         0
# Early_TaylorRehmet            0
# Election_TaylorRehmet         0
# TotalVotes_TaylorRehmet       0
# Absentee_LeighWambsganss      0
# Early_LeighWambsganss         0
# Election_LeighWambsganss      0
# TotalVotes_LeighWambsganss    0
# TotalVotesAll                 0
# VTD                           0
# CountyFIPS                    0
# County                        0
# CNTY                          0
# CNTYVTD                       0
# VTDKEY                        0
# total                         0
# anglo                         0
# nanglo                        0
# asian                         0
# black                         0
# hisp                          0
# bh                            0
# vap                           0
# anglovap                      0
# nanglovap                     0
# asianvap                      0
# blackvap                      0
# hispvap                       0
# bhvap                         0
# dtype: int64

# %%
# export csv
merged_df.to_csv('district9_election_census_2020.csv', index=False)

# %% [markdown]
# ## Demographic analysis

# %% [markdown]
# Column name meanings, from the Texas Legislative Council:
# - CountyFIPS (txt) - County FIPS Census Code
# - County (txt) - County name
# - CNTY (num) - County FIPS Census Code
# - VTD (txt) - VTD name (2024 general election)
# - CNTYVTD (txt) - Unique code used to join geographic data (CNTY + VTD)
# - VTDKEY (num) - Unique code used to join to geographic data
# - total (num) - Total Population
# - anglo (num) - Anglo Population
# - nanglo (num) - Non-Anglo Population
# - asian (num) - Asian Population
# - black (num) - Black Population
# - hispanic (num) - Hispanic Population
# - bh (num) - Black+Hispanic Population
# - vap (num) - Voting Age Population
# - anglovap (num) - Anglo Voting Age Population
# - nanglovap (num) - Non-Anglo Voting Age Population
# - asianvap (num) - Asian Voting Age Population
# - blackvap (num) - Black Voting Age Population
# - hispvap (num) - Hispanic Voting Age Population
# - bhvap (num) - Black+Hispanic Voting Age Population
#
# (going to assume anglo is a proxy for white)

# %%
merged_df.columns
# Out:
# Index(['Precinct', 'Registered_Voters', 'Absentee_TaylorRehmet',
#        'Early_TaylorRehmet', 'Election_TaylorRehmet',
#        'TotalVotes_TaylorRehmet', 'Absentee_LeighWambsganss',
#        'Early_LeighWambsganss', 'Election_LeighWambsganss',
#        'TotalVotes_LeighWambsganss', 'TotalVotesAll', 'VTD', 'CountyFIPS',
#        'County', 'CNTY', 'CNTYVTD', 'VTDKEY', 'total', 'anglo', 'nanglo',
#        'asian', 'black', 'hisp', 'bh', 'vap', 'anglovap', 'nanglovap',
#        'asianvap', 'blackvap', 'hispvap', 'bhvap'],
#       dtype='object')

# %%
merged_df.dtypes
# Out:
# Precinct                      object
# Registered_Voters             object
# Absentee_TaylorRehmet         object
# Early_TaylorRehmet            object
# Election_TaylorRehmet         object
# TotalVotes_TaylorRehmet       object
# Absentee_LeighWambsganss      object
# Early_LeighWambsganss         object
# Election_LeighWambsganss      object
# TotalVotes_LeighWambsganss    object
# TotalVotesAll                 object
# VTD                           object
# CountyFIPS                     int64
# County                        object
# CNTY                           int64
# CNTYVTD                       object
# VTDKEY                         int64
# total                          int64
# anglo                          int64
# nanglo                         int64
# asian                          int64
# black                          int64
# hisp                           int64
# bh                             int64
# vap                            int64
# anglovap                       int64
# nanglovap                      int64
# asianvap                       int64
# blackvap                       int64
# hispvap                        int64
# bhvap                          int64
# dtype: object

# %%
# create a column showing who won each precinct
merged_df['Winner'] = merged_df.apply(
    lambda row: 'Taylor Rehmet' if row['TotalVotes_TaylorRehmet'] > row['TotalVotes_LeighWambsganss']
    else ('Tie' if row['TotalVotes_TaylorRehmet'] == row['TotalVotes_LeighWambsganss']
    else 'Leigh Wambsganss'), 
    axis=1
)

# %%
rehmet_wins = merged_df[merged_df['Winner'] == 'Taylor Rehmet']
wambsganss_wins = merged_df[merged_df['Winner'] == 'Leigh Wambsganns']

# %%
# make col for percentage hispanic in each precinct
merged_df['pct_hisp'] = merged_df['hisp'] / merged_df['total']

# %%
# see which precincts are majority hispanice
majority_hispanic = merged_df[merged_df['pct_hisp'] > 0.5]

# %%
# 63 precincts are majority hispanic
majority_hispanic
# Out:
#     Precinct Registered_Voters Absentee_TaylorRehmet Early_TaylorRehmet  \
# 2       1008               314                     1                 12
# 4       1011              1134                     3                 19
# 5       1015              1188                     3                 68
# 6       1019               798                     1                  9
# 12      1066               985                     2                 29
# ..       ...               ...                   ...                ...
# 342     4620                81                     0                  2
# 351     4682               439                     1                 11
# 353     4685                 6                     0                  0
# 355     4687               260                     0                  8
# 356     4689               173                     0                  7
#
#     Election_TaylorRehmet TotalVotes_TaylorRehmet Absentee_LeighWambsganss  \
# 2                      24                      37                        0
# 4                      45                      67                        0
# 5                      72                     143                        0
# 6                      47                      57                        0
# 12                     49                      80                        0
# ..                    ...                     ...                      ...
# 342                     0                       2                        0
# 351                    16                      28                        2
# 353                     2                       2                        0
# 355                     9                      17                        1
# 356                     5                      12                        1
#
#     Early_LeighWambsganss Election_LeighWambsganss TotalVotes_LeighWambsganss  \
# 2                       0                        6                          6
# 4                       2                        3                          5
# 5                       3                       15                         18
# 6                       1                        5                          6
# 12                      5                       14                         19
# ..                    ...                      ...                        ...
# 342                     0                        0                          0
# 351                     5                        1                          8
# 353                     0                        0                          0
# 355                     0                        0                          1
# 356                     3                        4                          8
#
#      ...    bh   vap  anglovap nanglovap  asianvap blackvap  hispvap  bhvap  \
# 2    ...   536   421        38       383         7      147      227    371
# 4    ...  2891  2255       195      2060        51      370     1634   1999
# 5    ...  1269  1687       623      1064        60       83      900    976
# 6    ...  1860  1524       224      1300        14      166     1110   1264
# 12   ...  1843  1776       452      1324        55      381      879   1244
# ..   ...   ...   ...       ...       ...       ...      ...      ...    ...
# 342  ...   412   364        85       279         9       32      233    263
# 351  ...   819   720       141       579        40        7      532    539
# 353  ...    17     8         1         7         0        2        5      7
# 355  ...   563   514       114       400         2        3      392    394
# 356  ...   220   247        96       151         5        5      142    146
#
#             Winner  pct_hisp
# 2    Taylor Rehmet  0.604414
# 4    Taylor Rehmet  0.762835
# 5    Taylor Rehmet  0.564757
# 6    Taylor Rehmet  0.771970
# 12   Taylor Rehmet  0.560147
# ..             ...       ...
# 342  Taylor Rehmet  0.678899
# 351  Taylor Rehmet  0.790882
# 353  Taylor Rehmet  0.722222
# 355  Taylor Rehmet  0.776848
# 356  Taylor Rehmet  0.658537
#
# [66 rows x 33 columns]

# %%
# calculate vote shares and margins for majority hispanic precincts
# filter out precincts with zero votes to avoid division errors
majority_hispanic = majority_hispanic[majority_hispanic['TotalVotesAll'] > 0].copy()

# calculate vote share percentage for each candidate
majority_hispanic['Rehmet_Pct'] = (majority_hispanic['TotalVotes_TaylorRehmet'] / majority_hispanic['TotalVotesAll']) * 100
majority_hispanic['Wambsganss_Pct'] = (majority_hispanic['TotalVotes_LeighWambsganss'] / majority_hispanic['TotalVotesAll']) * 100

# margin is the difference between the two percentages
majority_hispanic['Vote_Margin_Pct'] = majority_hispanic['Rehmet_Pct'] - majority_hispanic['Wambsganss_Pct']

majority_hispanic[['Precinct', 'Winner', 'Rehmet_Pct', 'Wambsganss_Pct', 'Vote_Margin_Pct']]
# Out:
#     Precinct         Winner Rehmet_Pct Wambsganss_Pct Vote_Margin_Pct
# 2       1008  Taylor Rehmet  86.046512      13.953488       72.093023
# 4       1011  Taylor Rehmet  93.055556       6.944444       86.111111
# 5       1015  Taylor Rehmet  88.819876      11.180124       77.639752
# 6       1019  Taylor Rehmet   90.47619        9.52381       80.952381
# 12      1066  Taylor Rehmet  80.808081      19.191919       61.616162
# ..       ...            ...        ...            ...             ...
# 342     4620  Taylor Rehmet      100.0            0.0           100.0
# 351     4682  Taylor Rehmet  77.777778      22.222222       55.555556
# 353     4685  Taylor Rehmet      100.0            0.0           100.0
# 355     4687  Taylor Rehmet  94.444444       5.555556       88.888889
# 356     4689  Taylor Rehmet       60.0           40.0            20.0
#
# [63 rows x 5 columns]

# %%
# what about in majority non-white precincts?
merged_df['pct_nonwhite'] = merged_df['nanglo'] / merged_df['total']

# %%
majority_nonwhite = merged_df[merged_df['pct_nonwhite'] > 0.5]

# %%
# calculate vote shares and margins for majority nonwhite precincts
# filter out precincts with zero votes to avoid division errors
majority_nonwhite = majority_nonwhite[majority_nonwhite['TotalVotesAll'] > 0].copy()

# calculate vote share percentage for each candidate
majority_nonwhite['Rehmet_Pct'] = (majority_nonwhite['TotalVotes_TaylorRehmet'] / majority_nonwhite['TotalVotesAll']) * 100
majority_nonwhite['Wambsganss_Pct'] = (majority_nonwhite['TotalVotes_LeighWambsganss'] / majority_nonwhite['TotalVotesAll']) * 100

# margin is the difference between the two percentages
majority_nonwhite['Vote_Margin_Pct'] = majority_nonwhite['Rehmet_Pct'] - majority_nonwhite['Wambsganss_Pct']

majority_nonwhite[['Precinct', 'Winner', 'Rehmet_Pct', 'Wambsganss_Pct', 'Vote_Margin_Pct']]
# Out:
#     Precinct         Winner Rehmet_Pct Wambsganss_Pct Vote_Margin_Pct
# 1       1005  Taylor Rehmet  96.153846       3.846154       92.307692
# 2       1008  Taylor Rehmet  86.046512      13.953488       72.093023
# 3       1010  Taylor Rehmet  91.304348       8.695652       82.608696
# 4       1011  Taylor Rehmet  93.055556       6.944444       86.111111
# 5       1015  Taylor Rehmet  88.819876      11.180124       77.639752
# ..       ...            ...        ...            ...             ...
# 370     4829  Taylor Rehmet  68.846154      31.153846       37.692308
# 372     4832  Taylor Rehmet  72.105263      27.894737       44.210526
# 374     4836  Taylor Rehmet  62.202381      37.797619       24.404762
# 375     4844  Taylor Rehmet  61.170213      38.829787       22.340426
# 376     4846  Taylor Rehmet  64.084507      35.915493       28.169014
#
# [143 rows x 5 columns]

# %% [markdown]
# # Cleaning up shapefile to map

# %%
vtd_shapefile = gpd.read_file('vtds_24pg/VTDs_24PG.shp')

# %%
vtd_shapefile.columns
# Out:
# Index(['CNTY', 'COLOR', 'VTD', 'CNTYKEY', 'VTDKEY', 'CNTYVTD', 'Shape_area',
#        'Shape_len', 'geometry'],
#       dtype='object')

# %%
vtd_shapefile.head()
# Out:
#    CNTY  COLOR   VTD  CNTYKEY  VTDKEY CNTYVTD    Shape_area     Shape_len  \
# 0     1      4  0001        1     1.0   10001  5.666216e+06  15288.088777
# 1     1      3  0002        1     2.0   10002  2.562129e+08  94434.420881
# 2     1      6  0003        1     3.0   10003  7.072228e+07  55660.372406
# 3     1      2  0004        1     4.0   10004  2.410662e+08  91319.549282
# 4     1      1  0005        1     5.0   10005  1.689854e+08  86937.648556
#
#                                             geometry
# 0  POLYGON ((1413960.808 1073012.816, 1413971.571...
# 1  POLYGON ((1420165.429 1066385.798, 1420251.968...
# 2  POLYGON ((1416579.79 1072023.104, 1416744.635 ...
# 3  POLYGON ((1435674.876 1074608.545, 1435714.039...
# 4  POLYGON ((1436888.342 1072498.734, 1436911.364...

# %%
# again, filter for the tarrant county precincts only

vtd_shapefile = vtd_shapefile[vtd_shapefile['CNTYKEY'] == 220]

# %%
vtd_shapefile
# Out:
#       CNTY  COLOR    VTD  CNTYKEY  VTDKEY   CNTYVTD    Shape_area  \
# 7894   439      2   1001      220  7895.0   2201001  1.937824e+06
# 7895   439      7   1004      220  7896.0   2201004  1.662849e+06
# 7896   439      3   1005      220  7897.0   2201005  7.781609e+05
# 7897   439      1   1008      220  7898.0   2201008  5.076940e+05
# 7898   439      7   1009      220  7899.0   2201009  2.023068e+06
# ...    ...    ...    ...      ...     ...       ...           ...
# 8671   439      6   4836      220  8672.0   2204836  4.208066e+06
# 8672   439      3   4844      220  8673.0   2204844  1.405128e+06
# 8673   439      4  4846A      220  8674.0  2204846A  3.065566e+06
# 8674   439      3  4846B      220  8675.0  2204846B  6.146796e+05
# 8675   439      5   4849      220  8676.0   2204849  2.000424e+06
#
#          Shape_len                                           geometry
# 7894   6354.370530  POLYGON ((1250450.258 1178991.523, 1250472.418...
# 7895   5512.518617  POLYGON ((1245985.98 1168494.437, 1246035.435 ...
# 7896   3551.069974  POLYGON ((1251617.859 1177440.297, 1251647.258...
# 7897   4410.838432  POLYGON ((1252370.551 1179539.611, 1252373.288...
# 7898   9450.698814  POLYGON ((1238360.991 1174306.174, 1238359.144...
# ...            ...                                                ...
# 8671  12792.096333  POLYGON ((1250655.361 1190545.932, 1250826.208...
# 8672   5349.549695  POLYGON ((1241300.598 1189373.984, 1241302.425...
# 8673   9391.020778  POLYGON ((1251818.83 1190577.208, 1251825.72 1...
# 8674   4413.983739  POLYGON ((1251551.016 1186817.896, 1251551.922...
# 8675   5713.398669  POLYGON ((1246215.675 1197455.214, 1246346.172...
#
# [782 rows x 9 columns]

# %%
# we need to account for the suffixes again 
# ensure we have a single VTD column (keep the first)
vtd_shapefile = vtd_shapefile.loc[:, ~vtd_shapefile.columns.duplicated()]

vtd_shapefile['VTD'] = vtd_shapefile['VTD'].astype(str)
vtd_shapefile['VTD_base'] = vtd_shapefile['VTD'].str.replace(r'\s*[AB]\s*$', '', regex=True)

vtd_shapefile = vtd_shapefile.dissolve(by='VTD_base', as_index=False)
vtd_shapefile.rename(columns={'VTD_base': 'VTD'}, inplace=True)
vtd_shapefile = vtd_shapefile.loc[:, ~vtd_shapefile.columns.duplicated()]

# %%
vtd_shapefile
# Out:
#       VTD                                           geometry  CNTY  COLOR  \
# 0    1001  POLYGON ((1250450.258 1178991.523, 1250472.418...   439      2
# 1    1004  POLYGON ((1245985.98 1168494.437, 1246035.435 ...   439      7
# 2    1005  POLYGON ((1251617.859 1177440.297, 1251647.258...   439      3
# 3    1008  POLYGON ((1252370.551 1179539.611, 1252373.288...   439      1
# 4    1009  POLYGON ((1238360.991 1174306.174, 1238359.144...   439      7
# ..    ...                                                ...   ...    ...
# 772  4833  POLYGON ((1229636.711 1186103.143, 1229676.615...   439      7
# 773  4836  POLYGON ((1250655.361 1190545.932, 1250826.208...   439      6
# 774  4844  POLYGON ((1241300.598 1189373.984, 1241302.425...   439      3
# 775  4846  MULTIPOLYGON (((1251551.922 1186765.315, 12515...   439      4
# 776  4849  POLYGON ((1246215.675 1197455.214, 1246346.172...   439      5
#
#      CNTYKEY  VTDKEY   CNTYVTD    Shape_area     Shape_len
# 0        220  7895.0   2201001  1.937824e+06   6354.370530
# 1        220  7896.0   2201004  1.662849e+06   5512.518617
# 2        220  7897.0   2201005  7.781609e+05   3551.069974
# 3        220  7898.0   2201008  5.076940e+05   4410.838432
# 4        220  7899.0   2201009  2.023068e+06   9450.698814
# ..       ...     ...       ...           ...           ...
# 772      220  8671.0   2204833  2.634667e+07  21813.330872
# 773      220  8672.0   2204836  4.208066e+06  12792.096333
# 774      220  8673.0   2204844  1.405128e+06   5349.549695
# 775      220  8674.0  2204846A  3.065566e+06   9391.020778
# 776      220  8676.0   2204849  2.000424e+06   5713.398669
#
# [777 rows x 9 columns]

# %%
# plot shapefile to check it looks right
vtd_shapefile.plot()
# Out:
# <Axes: >

# %%
# looks good! now, let's join with merged_df to get election results and demographics
vtd_shapefile = vtd_shapefile.merge(merged_df, left_on='VTD', right_on='VTD', how='inner')

# %%
# plot winners by precinct to ensure it looks right
color_map = {
    'Taylor Rehmet': 'red',
    'Leigh Wambsganss': 'blue',
    'Tie': 'gray'
}

colors = vtd_shapefile['Winner'].map(color_map)
vtd_shapefile.plot(color=colors)
# Out:
# <Axes: >
